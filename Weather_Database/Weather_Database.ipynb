# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
from citipy import citipy
from datetime import datetime

# Import the API key.
from config import g_key
from config import weather_api_key

# %% [markdown]
# ## Generate 2,000 coordinates

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %% [markdown]
# ## Find cities

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | paita
# Processing Record 2 of Set 15 | tiarei
# Processing Record 3 of Set 15 | dingle
# Processing Record 4 of Set 15 | punta arenas
# Processing Record 5 of Set 15 | rikitea
# Processing Record 6 of Set 15 | durant
# Processing Record 7 of Set 15 | mataura
# Processing Record 8 of Set 15 | pevek
# Processing Record 9 of Set 15 | hermanus
# Processing Record 10 of Set 15 | hilo
# Processing Record 11 of Set 15 | kapaa
# Processing Record 12 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 15 | chokurdakh
# Processing Record 14 of Set 15 | flin flon
# Processing Record 15 of Set 15 | sitka
# Processing Record 16 of Set 15 | vila franca do campo
# Processing Record 17 of Set 15 | esperance
# Processing Record 18 of Set 15 | lavrentiya
# Processing Record 19 of Set 15 | panjab
# Processing Record 20 of Set 15 | waipawa
# Processing Record 21 of Set 15 | nyimba
# Processing Record 22 of Set 15 | port-gentil
# Processing Record 23 of Set 15 | sarkand
# Processing Record 24 of Set 15 | albany
# Processing Record 25 of Set 15 | punta de piedra
# Processing Record 26 of Set 15 | kommunar
# Processing Record 27 of Set 15 | kirakira
# Processing Record 28 of Set 15 | bredasdorp
# Processing Record 29 of Set 15 | cidreira
# Processing Record 30 of Set 15 | tiksi
# Processing Record 31 of Set 15 | castro
# Processing Record 32 of Set 15 | busselton
# Processing Record 33 of Set 15 | tuktoyaktuk
# Processing Record 34 of Set 15 | novyye lyady
# Processing Record 35 of Set 15 | channel-port aux basques
# Processing Record 36 of Set 15 | ushuaia
# Processing Record 37 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 15 | seoul
# Processing Record 40 of Set 15 | muleba
# Processing Record 41 of Set 15 | tupancireta
# Processing Record 42 of Set 15 | hovd
# Processing Record 43 of Set 15 | saskylakh
# Processing Record 44 of Set 15 | yangambi
# Processing Record 45 of Set 15 | qaanaaq
# Processing Record 46 of Set 15 | ballybofey
# Processing Record 47 of Set 15 | coihaique
# Processing Record 48 of Set 15 | hampton
# Processing Record 49 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 15 | hobart
# Processing Record 1 of Set 16 | ilulissat
# Processing Record 2 of Set 16 | trairi
# Processing Record 3 of Set 16 | tsaritsani
# Processing Record 4 of Set 16 | avarua
# Processing Record 5 of Set 16 | atuona
# Processing Record 6 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 16 | saint-philippe
# Processing Record 8 of Set 16 | puerto ayora
# Processing Record 9 of Set 16 | vaini
# Processing Record 10 of Set 16 | celestun
# Processing Record 11 of Set 16 | grand gaube
# Processing Record 12 of Set 16 | port alfred
# Processing Record 13 of Set 16 | laguna
# Processing Record 14 of Set 16 | airai
# Processing Record 15 of Set 16 | abu samrah
# Processing Record 16 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 16 | saint-augustin
# Processing Record 18 of Set 16 | jamalpur
# Processing Record 19 of Set 16 | samarinda
# Processing Record 20 of Set 16 | nanortalik
# Processing Record 21 of Set 16 | port elizabeth
# Processing Record 22 of Set 16 | bluff
# Processing Record 23 of Set 16 | armacao dos buzios
# City not found. Skipping...
# Processing Record 24 of Set 16 | yellowknife
# Processing Record 25 of Set 16 | mar del plata
# Processing Record 26 of Set 16 | victoria
# Processing Record 27 of Set 16 | labuhan
# Processing Record 28 of Set 16 | half moon bay
# Processing Record 29 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 16 | semnan
# Processing Record 31 of Set 16 | ahuimanu
# Processing Record 32 of Set 16 | kaeo
# Processing Record 33 of Set 16 | ginir
# Processing Record 34 of Set 16 | carnarvon
# Processing Record 35 of Set 16 | ovre ardal
# Processing Record 36 of Set 16 | hithadhoo
# Processing Record 37 of Set 16 | guerrero negro
# Processing Record 38 of Set 16 | kahului
# Processing Record 39 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 16 | saint anthony
# Processing Record 41 of Set 16 | ribeira grande
# Processing Record 42 of Set 16 | tasiilaq
# Processing Record 43 of Set 16 | rio gallegos
# Processing Record 44 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 16 | cape town
# Processing Record 46 of Set 16 | geraldton
# Processing Record 47 of Set 16 | sao gabriel da cachoeira
# Processing Record 48 of Set 16 | arraial do cabo
# Processing Record 49 of Set 16 | cabo san lucas
# Processing Record 50 of Set 16 | plettenberg bay
# Processing Record 1 of Set 17 | twin falls
# Processing Record 2 of Set 17 | narsaq
# Processing Record 3 of Set 17 | sioux lookout
# Processing Record 4 of Set 17 | chakulia
# Processing Record 5 of Set 17 | lagoa
# Processing Record 6 of Set 17 | kruisfontein
# Processing Record 7 of Set 17 | panaba
# Processing Record 8 of Set 17 | yar-sale
# Processing Record 9 of Set 17 | khatanga
# Processing Record 10 of Set 17 | bandarbeyla
# Processing Record 11 of Set 17 | moranbah
# Processing Record 12 of Set 17 | inirida
# Processing Record 13 of Set 17 | berdigestyakh
# Processing Record 14 of Set 17 | lasa
# Processing Record 15 of Set 17 | nantucket
# Processing Record 16 of Set 17 | malakal
# Processing Record 17 of Set 17 | neyshabur
# Processing Record 18 of Set 17 | peski
# Processing Record 19 of Set 17 | constitucion
# Processing Record 20 of Set 17 | ramotswa
# Processing Record 21 of Set 17 | mnogovershinnyy
# Processing Record 22 of Set 17 | along
# Processing Record 23 of Set 17 | miranda
# Processing Record 24 of Set 17 | hofn
# Processing Record 25 of Set 17 | new norfolk
# Processing Record 26 of Set 17 | bone
# Processing Record 27 of Set 17 | acari
# Processing Record 28 of Set 17 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 17 | lebu
# Processing Record 30 of Set 17 | prata
# Processing Record 31 of Set 17 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 17 | mahebourg
# Processing Record 33 of Set 17 | batagay-alyta
# Processing Record 34 of Set 17 | saldanha
# Processing Record 35 of Set 17 | lagos
# Processing Record 36 of Set 17 | ubinskoye
# Processing Record 37 of Set 17 | butaritari
# Processing Record 38 of Set 17 | katherine
# Processing Record 39 of Set 17 | urengoy
# Processing Record 40 of Set 17 | southbridge
# Processing Record 41 of Set 17 | aabybro
# Processing Record 42 of Set 17 | cuamba
# Processing Record 43 of Set 17 | hualmay
# Processing Record 44 of Set 17 | fairbanks
# Processing Record 45 of Set 17 | coquimbo
# Processing Record 46 of Set 17 | caravelas
# Processing Record 47 of Set 17 | presidencia roque saenz pena
# Processing Record 48 of Set 17 | bogovarovo
# Processing Record 49 of Set 17 | bethel
# Processing Record 50 of Set 17 | bilibino
# Processing Record 1 of Set 18 | talnakh
# Processing Record 2 of Set 18 | gat
# Processing Record 3 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 18 | portobelo
# Processing Record 6 of Set 18 | farmington
# Processing Record 7 of Set 18 | tura
# Processing Record 8 of Set 18 | te anau
# Processing Record 9 of Set 18 | rocha
# Processing Record 10 of Set 18 | agustin codazzi
# Processing Record 11 of Set 18 | kuryk
# Processing Record 12 of Set 18 | meulaboh
# Processing Record 13 of Set 18 | ternate
# Processing Record 14 of Set 18 | tabou
# Processing Record 15 of Set 18 | kavieng
# Processing Record 16 of Set 18 | severo-kurilsk
# Processing Record 17 of Set 18 | college
# Processing Record 18 of Set 18 | charters towers
# Processing Record 19 of Set 18 | johnson city
# Processing Record 20 of Set 18 | kaitangata
# Processing Record 21 of Set 18 | sao jose do belmonte
# Processing Record 22 of Set 18 | chuy
# Processing Record 23 of Set 18 | sarakhs
# Processing Record 24 of Set 18 | ancud
# Processing Record 25 of Set 18 | arona
# Processing Record 26 of Set 18 | russell
# Processing Record 27 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 18 | sunbury
# Processing Record 29 of Set 18 | prince rupert
# Processing Record 30 of Set 18 | sept-iles
# Processing Record 31 of Set 18 | siderno
# Processing Record 32 of Set 18 | ponta do sol
# Processing Record 33 of Set 18 | san borja
# Processing Record 34 of Set 18 | muncar
# Processing Record 35 of Set 18 | itoman
# Processing Record 36 of Set 18 | codajas
# Processing Record 37 of Set 18 | ketchikan
# Processing Record 38 of Set 18 | calamar
# Processing Record 39 of Set 18 | ust-kulom
# Processing Record 40 of Set 18 | savinskiy
# Processing Record 41 of Set 18 | tondano
# Processing Record 42 of Set 18 | saint-francois
# Processing Record 43 of Set 18 | kenner
# Processing Record 44 of Set 18 | bengkulu
# Processing Record 45 of Set 18 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 18 | mahajanga
# Processing Record 47 of Set 18 | nome
# Processing Record 48 of Set 18 | lorengau
# Processing Record 49 of Set 18 | east london
# Processing Record 50 of Set 18 | souillac
# Processing Record 1 of Set 19 | palmer
# Processing Record 2 of Set 19 | dikson
# Processing Record 3 of Set 19 | chenzhou
# Processing Record 4 of Set 19 | casper
# Processing Record 5 of Set 19 | leningradskiy
# Processing Record 6 of Set 19 | vao
# Processing Record 7 of Set 19 | conde
# Processing Record 8 of Set 19 | provideniya
# Processing Record 9 of Set 19 | businga
# Processing Record 10 of Set 19 | griffith
# Processing Record 11 of Set 19 | burns lake
# Processing Record 12 of Set 19 | sola
# Processing Record 13 of Set 19 | ambulu
# Processing Record 14 of Set 19 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 19 | mount gambier
# Processing Record 16 of Set 19 | kampong cham
# Processing Record 17 of Set 19 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 19 | ronne
# Processing Record 19 of Set 19 | norrtalje
# Processing Record 20 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 19 | nikolskoye
# Processing Record 22 of Set 19 | alofi
# Processing Record 23 of Set 19 | bissora
# Processing Record 24 of Set 19 | taoudenni
# Processing Record 25 of Set 19 | el campo
# Processing Record 26 of Set 19 | gribanovskiy
# Processing Record 27 of Set 19 | tilichiki
# Processing Record 28 of Set 19 | turukhansk
# Processing Record 29 of Set 19 | cherskiy
# Processing Record 30 of Set 19 | peringat
# Processing Record 31 of Set 19 | jamestown
# Processing Record 32 of Set 19 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 19 | georgetown
# Processing Record 35 of Set 19 | sakakah
# Processing Record 36 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 19 | blytheville
# Processing Record 38 of Set 19 | umea
# Processing Record 39 of Set 19 | mount pleasant
# Processing Record 40 of Set 19 | horta
# Processing Record 41 of Set 19 | breyten
# Processing Record 42 of Set 19 | yabassi
# Processing Record 43 of Set 19 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 19 | tautira
# Processing Record 45 of Set 19 | hasaki
# Processing Record 46 of Set 19 | norman wells
# Processing Record 47 of Set 19 | mosalsk
# Processing Record 48 of Set 19 | paamiut
# Processing Record 49 of Set 19 | kannod
# Processing Record 50 of Set 19 | thompson
# Processing Record 1 of Set 20 | yasnyy
# Processing Record 2 of Set 20 | rawson
# Processing Record 3 of Set 20 | rincon
# Processing Record 4 of Set 20 | xuddur
# Processing Record 5 of Set 20 | upernavik
# Processing Record 6 of Set 20 | ambilobe
# Processing Record 7 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 20 | sena madureira
# Processing Record 9 of Set 20 | yarim
# Processing Record 10 of Set 20 | baoqing
# Processing Record 11 of Set 20 | qaqortoq
# Processing Record 12 of Set 20 | katsuura
# Processing Record 13 of Set 20 | sao joao da barra
# Processing Record 14 of Set 20 | kyren
# Processing Record 15 of Set 20 | atar
# Processing Record 16 of Set 20 | sao filipe
# Processing Record 17 of Set 20 | clyde river
# Processing Record 18 of Set 20 | puri
# Processing Record 19 of Set 20 | gisborne
# Processing Record 20 of Set 20 | san cristobal
# Processing Record 21 of Set 20 | la ronge
# Processing Record 22 of Set 20 | nizwa
# Processing Record 23 of Set 20 | port-cartier
# Processing Record 24 of Set 20 | chimbote
# Processing Record 25 of Set 20 | miquelon
# Processing Record 26 of Set 20 | tansen
# Processing Record 27 of Set 20 | komsomolskiy
# Processing Record 28 of Set 20 | chara
# Processing Record 29 of Set 20 | salo
# Processing Record 30 of Set 20 | zaoyang
# Processing Record 31 of Set 20 | bukachacha
# Processing Record 32 of Set 20 | batemans bay
# Processing Record 33 of Set 20 | alugan
# Processing Record 34 of Set 20 | devonport
# Processing Record 35 of Set 20 | zaraza
# Processing Record 36 of Set 20 | gander
# Processing Record 37 of Set 20 | padang
# Processing Record 38 of Set 20 | iqaluit
# Processing Record 39 of Set 20 | adrar
# Processing Record 40 of Set 20 | havre-saint-pierre
# Processing Record 41 of Set 20 | krasnoselkup
# Processing Record 42 of Set 20 | point pleasant
# Processing Record 43 of Set 20 | santiago
# Processing Record 44 of Set 20 | addi ugri
# City not found. Skipping...
# Processing Record 45 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 20 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 20 | ballstad
# City not found. Skipping...
# Processing Record 48 of Set 20 | vilanova del cami
# Processing Record 49 of Set 20 | kitimat
# Processing Record 50 of Set 20 | tual
# Processing Record 1 of Set 21 | margate
# Processing Record 2 of Set 21 | roth
# Processing Record 3 of Set 21 | orlik
# Processing Record 4 of Set 21 | nouadhibou
# Processing Record 5 of Set 21 | binzhou
# Processing Record 6 of Set 21 | goma
# Processing Record 7 of Set 21 | cascais
# Processing Record 8 of Set 21 | salamiyah
# Processing Record 9 of Set 21 | avera
# Processing Record 10 of Set 21 | beringovskiy
# Processing Record 11 of Set 21 | fortuna
# Processing Record 12 of Set 21 | machali
# Processing Record 13 of Set 21 | xingyi
# Processing Record 14 of Set 21 | morondava
# Processing Record 15 of Set 21 | usevya
# Processing Record 16 of Set 21 | hay river
# Processing Record 17 of Set 21 | luganville
# Processing Record 18 of Set 21 | moerai
# Processing Record 19 of Set 21 | kushmurun
# Processing Record 20 of Set 21 | tobol
# Processing Record 21 of Set 21 | san quintin
# Processing Record 22 of Set 21 | santa ines
# Processing Record 23 of Set 21 | kulhudhuffushi
# Processing Record 24 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 21 | muzhi
# Processing Record 26 of Set 21 | grafton
# Processing Record 27 of Set 21 | whitehorse
# Processing Record 28 of Set 21 | faro
# Processing Record 29 of Set 21 | eldoret
# Processing Record 30 of Set 21 | grindavik
# Processing Record 31 of Set 21 | diffa
# Processing Record 32 of Set 21 | eyl
# Processing Record 33 of Set 21 | moose factory
# Processing Record 34 of Set 21 | barrow
# Processing Record 35 of Set 21 | awjilah
# Processing Record 36 of Set 21 | luderitz
# Processing Record 37 of Set 21 | shambu
# Processing Record 38 of Set 21 | charyshskoye
# Processing Record 39 of Set 21 | rovaniemi
# Processing Record 40 of Set 21 | waitati
# Processing Record 41 of Set 21 | san patricio
# Processing Record 42 of Set 21 | longyearbyen
# Processing Record 43 of Set 21 | acarau
# Processing Record 44 of Set 21 | omboue
# Processing Record 45 of Set 21 | coos bay
# Processing Record 46 of Set 21 | muros
# Processing Record 47 of Set 21 | rongcheng
# Processing Record 48 of Set 21 | maningrida
# Processing Record 49 of Set 21 | barquisimeto
# Processing Record 50 of Set 21 | sibolga
# Processing Record 1 of Set 22 | goderich
# Processing Record 2 of Set 22 | chisinau
# Processing Record 3 of Set 22 | saurimo
# Processing Record 4 of Set 22 | nuuk
# Processing Record 5 of Set 22 | sisimiut
# Processing Record 6 of Set 22 | georgiyevka
# Processing Record 7 of Set 22 | salalah
# Processing Record 8 of Set 22 | duiwelskloof
# Processing Record 9 of Set 22 | obala
# Processing Record 10 of Set 22 | middle island
# Processing Record 11 of Set 22 | port blair
# Processing Record 12 of Set 22 | kuruman
# Processing Record 13 of Set 22 | albanel
# Processing Record 14 of Set 22 | touros
# Processing Record 15 of Set 22 | krasnovishersk
# Processing Record 16 of Set 22 | yining
# Processing Record 17 of Set 22 | cayenne
# Processing Record 18 of Set 22 | guozhen
# Processing Record 19 of Set 22 | kuala terengganu
# Processing Record 20 of Set 22 | dutse
# Processing Record 21 of Set 22 | general pico
# Processing Record 22 of Set 22 | aklavik
# Processing Record 23 of Set 22 | vardo
# Processing Record 24 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 22 | praia da vitoria
# Processing Record 26 of Set 22 | ponta delgada
# Processing Record 27 of Set 22 | pathankot
# Processing Record 28 of Set 22 | beaverlodge
# Processing Record 29 of Set 22 | jiwani
# Processing Record 30 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 22 | sur
# Processing Record 32 of Set 22 | ajdabiya
# Processing Record 33 of Set 22 | the valley
# Processing Record 34 of Set 22 | lodja
# Processing Record 35 of Set 22 | san felix
# Processing Record 36 of Set 22 | faanui
# Processing Record 37 of Set 22 | thai nguyen
# Processing Record 38 of Set 22 | shaoyang
# Processing Record 39 of Set 22 | namibe
# Processing Record 40 of Set 22 | raton
# Processing Record 41 of Set 22 | buarcos
# Processing Record 42 of Set 22 | bairiki
# Processing Record 43 of Set 22 | springdale
# Processing Record 44 of Set 22 | jimma
# Processing Record 45 of Set 22 | kudahuvadhoo
# Processing Record 46 of Set 22 | mandalgovi
# Processing Record 47 of Set 22 | cloquet
# Processing Record 48 of Set 22 | tuban
# Processing Record 49 of Set 22 | kidal
# Processing Record 50 of Set 22 | khandyga
# Processing Record 1 of Set 23 | pangkalanbuun
# Processing Record 2 of Set 23 | nichinan
# Processing Record 3 of Set 23 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 23 | francisco sa
# Processing Record 5 of Set 23 | englewood
# Processing Record 6 of Set 23 | namatanai
# Processing Record 7 of Set 23 | mayo
# Processing Record 8 of Set 23 | mitla
# Processing Record 9 of Set 23 | fort wellington
# Processing Record 10 of Set 23 | rafai
# Processing Record 11 of Set 23 | najran
# Processing Record 12 of Set 23 | marawi
# Processing Record 13 of Set 23 | lamar
# Processing Record 14 of Set 23 | fenoarivo
# Processing Record 15 of Set 23 | ksenyevka
# City not found. Skipping...
# Processing Record 16 of Set 23 | bosobolo
# Processing Record 17 of Set 23 | saint-georges
# Processing Record 18 of Set 23 | burlington
# Processing Record 19 of Set 23 | lugo
# Processing Record 20 of Set 23 | san juan
# Processing Record 21 of Set 23 | krasnyy chikoy
# Processing Record 22 of Set 23 | saint george
# Processing Record 23 of Set 23 | le port
# Processing Record 24 of Set 23 | dongsheng
# Processing Record 25 of Set 23 | gamba
# Processing Record 26 of Set 23 | torbay
# Processing Record 27 of Set 23 | pangnirtung
# Processing Record 28 of Set 23 | ornes
# Processing Record 29 of Set 23 | boyabat
# Processing Record 30 of Set 23 | hamilton
# Processing Record 31 of Set 23 | ponerihouen
# Processing Record 32 of Set 23 | sindor
# Processing Record 33 of Set 23 | solnechnyy
# Processing Record 34 of Set 23 | devils lake
# Processing Record 35 of Set 23 | puerto escondido
# Processing Record 36 of Set 23 | birao
# Processing Record 37 of Set 23 | babai
# Processing Record 38 of Set 23 | vilcun
# Processing Record 39 of Set 23 | moindou
# Processing Record 40 of Set 23 | kenai
# Processing Record 41 of Set 23 | san joaquin
# Processing Record 42 of Set 23 | chabahar
# Processing Record 43 of Set 23 | broome
# Processing Record 44 of Set 23 | quime
# Processing Record 45 of Set 23 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 23 | tamandare
# Processing Record 47 of Set 23 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 23 | hobyo
# Processing Record 49 of Set 23 | whitecourt
# Processing Record 50 of Set 23 | vaitape
# Processing Record 1 of Set 24 | praia
# Processing Record 2 of Set 24 | katangli
# Processing Record 3 of Set 24 | odweyne
# Processing Record 4 of Set 24 | abhar
# Processing Record 5 of Set 24 | bridgton
# Processing Record 6 of Set 24 | port lincoln
# Processing Record 7 of Set 24 | paucartambo
# City not found. Skipping...
# Processing Record 8 of Set 24 | burnie
# Processing Record 9 of Set 24 | brae
# Processing Record 10 of Set 24 | skelleftea
# Processing Record 11 of Set 24 | port hardy
# Processing Record 12 of Set 24 | opuwo
# Processing Record 13 of Set 24 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 24 | havelock
# Processing Record 15 of Set 24 | jhunjhunun
# Processing Record 16 of Set 24 | san jose
# Processing Record 17 of Set 24 | beisfjord
# Processing Record 18 of Set 24 | caceres
# Processing Record 19 of Set 24 | hervey bay
# Processing Record 20 of Set 24 | shingu
# Processing Record 21 of Set 24 | buala
# Processing Record 22 of Set 24 | byron bay
# Processing Record 23 of Set 24 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 24 | vila velha
# Processing Record 25 of Set 24 | perth
# Processing Record 26 of Set 24 | srednekolymsk
# Processing Record 27 of Set 24 | urumqi
# Processing Record 28 of Set 24 | burica
# City not found. Skipping...
# Processing Record 29 of Set 24 | pisco
# Processing Record 30 of Set 24 | poum
# Processing Record 31 of Set 24 | tucurui
# Processing Record 32 of Set 24 | glyadyanskoye
# Processing Record 33 of Set 24 | san pedro
# Processing Record 34 of Set 24 | cheney
# Processing Record 35 of Set 24 | yunjinghong
# City not found. Skipping...
# Processing Record 36 of Set 24 | filadelfia
# Processing Record 37 of Set 24 | asau
# Processing Record 38 of Set 24 | ambon
# Processing Record 39 of Set 24 | daigo
# Processing Record 40 of Set 24 | kodiak
# Processing Record 41 of Set 24 | viedma
# Processing Record 42 of Set 24 | fayaoue
# Processing Record 43 of Set 24 | thessalon
# Processing Record 44 of Set 24 | kiunga
# Processing Record 45 of Set 24 | condado
# Processing Record 46 of Set 24 | egvekinot
# Processing Record 47 of Set 24 | peniche
# Processing Record 48 of Set 24 | colgong
# Processing Record 49 of Set 24 | la palma
# Processing Record 50 of Set 24 | lompoc
# Processing Record 1 of Set 25 | pendencias
# Processing Record 2 of Set 25 | santa cruz
# Processing Record 3 of Set 25 | sorland
# Processing Record 4 of Set 25 | zhuanghe
# Processing Record 5 of Set 25 | mezen
# Processing Record 6 of Set 25 | ekibastuz
# Processing Record 7 of Set 25 | nacala
# Processing Record 8 of Set 25 | kiruna
# Processing Record 9 of Set 25 | jansath
# Processing Record 10 of Set 25 | tazmalt
# Processing Record 11 of Set 25 | valdivia
# Processing Record 12 of Set 25 | miles city
# Processing Record 13 of Set 25 | jalu
# Processing Record 14 of Set 25 | camara de lobos
# Processing Record 15 of Set 25 | zyryanka
# Processing Record 16 of Set 25 | anloga
# Processing Record 17 of Set 25 | jumla
# Processing Record 18 of Set 25 | taman
# Processing Record 19 of Set 25 | colquechaca
# Processing Record 20 of Set 25 | boa esperanca
# Processing Record 21 of Set 25 | malanje
# Processing Record 22 of Set 25 | ewa beach
# Processing Record 23 of Set 25 | lesnoy
# Processing Record 24 of Set 25 | rio muerto
# Processing Record 25 of Set 25 | onufriyivka
# Processing Record 26 of Set 25 | irati
# Processing Record 27 of Set 25 | tombouctou
# Processing Record 28 of Set 25 | talara
# Processing Record 29 of Set 25 | isabela
# Processing Record 30 of Set 25 | trincomalee
# Processing Record 31 of Set 25 | acapulco
# Processing Record 32 of Set 25 | harper
# Processing Record 33 of Set 25 | faya
# Processing Record 34 of Set 25 | muravlenko
# Processing Record 35 of Set 25 | cacoal
# Processing Record 36 of Set 25 | aqtobe
# Processing Record 37 of Set 25 | vanimo
# Processing Record 38 of Set 25 | corning
# Processing Record 39 of Set 25 | great yarmouth
# Processing Record 40 of Set 25 | tianmen
# Processing Record 41 of Set 25 | ugoofaaru
# Processing Record 42 of Set 25 | natal
# Processing Record 43 of Set 25 | tommot
# Processing Record 44 of Set 25 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 25 | wankaner
# Processing Record 46 of Set 25 | mashhad
# Processing Record 47 of Set 25 | huilong
# Processing Record 48 of Set 25 | koundara
# Processing Record 49 of Set 25 | zhanaozen
# Processing Record 50 of Set 25 | mangan
# Processing Record 1 of Set 26 | aswan
# Processing Record 2 of Set 26 | yumen
# Processing Record 3 of Set 26 | oyama
# Processing Record 4 of Set 26 | torbat-e jam
# Processing Record 5 of Set 26 | denpasar
# Processing Record 6 of Set 26 | matara
# Processing Record 7 of Set 26 | olafsvik
# Processing Record 8 of Set 26 | drawsko pomorskie
# Processing Record 9 of Set 26 | tecoanapa
# Processing Record 10 of Set 26 | bom jesus
# Processing Record 11 of Set 26 | yulara
# Processing Record 12 of Set 26 | ostrovnoy
# Processing Record 13 of Set 26 | huejuquilla el alto
# Processing Record 14 of Set 26 | bahia honda
# Processing Record 15 of Set 26 | houma
# Processing Record 16 of Set 26 | mangrol
# Processing Record 17 of Set 26 | russkaya polyana
# Processing Record 18 of Set 26 | matamoros
# Processing Record 19 of Set 26 | karratha
# Processing Record 20 of Set 26 | pacifica
# Processing Record 21 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 26 | kamenka
# Processing Record 23 of Set 26 | boralday
# Processing Record 24 of Set 26 | svolvaer
# Processing Record 25 of Set 26 | nador
# Processing Record 26 of Set 26 | trenggalek
# Processing Record 27 of Set 26 | kerrville
# Processing Record 28 of Set 26 | tchollire
# Processing Record 29 of Set 26 | dicabisagan
# Processing Record 30 of Set 26 | aosta
# Processing Record 31 of Set 26 | sobolevo
# Processing Record 32 of Set 26 | itarema
# Processing Record 33 of Set 26 | coahuayana
# Processing Record 34 of Set 26 | general roca
# Processing Record 35 of Set 26 | isla mujeres
# Processing Record 36 of Set 26 | shkotovo-22
# City not found. Skipping...
# Processing Record 37 of Set 26 | havoysund
# Processing Record 38 of Set 26 | zhezkazgan
# Processing Record 39 of Set 26 | turbat
# Processing Record 40 of Set 26 | saint-joseph
# Processing Record 41 of Set 26 | severodvinsk
# Processing Record 42 of Set 26 | kamaishi
# Processing Record 43 of Set 26 | moyale
# Processing Record 44 of Set 26 | malyye derbety
# Processing Record 45 of Set 26 | oystese
# Processing Record 46 of Set 26 | serowe
# Processing Record 47 of Set 26 | escarcega
# Processing Record 48 of Set 26 | quelimane
# Processing Record 49 of Set 26 | magadan
# Processing Record 50 of Set 26 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 27 | auki
# Processing Record 2 of Set 27 | fort nelson
# Processing Record 3 of Set 27 | caraballeda
# Processing Record 4 of Set 27 | nakasongola
# Processing Record 5 of Set 27 | morgan city
# Processing Record 6 of Set 27 | victor harbor
# Processing Record 7 of Set 27 | kundian
# Processing Record 8 of Set 27 | isangel
# Processing Record 9 of Set 27 | altay
# Processing Record 10 of Set 27 | kavaratti
# Processing Record 11 of Set 27 | irkutsk
# Processing Record 12 of Set 27 | cayeli
# Processing Record 13 of Set 27 | richards bay
# Processing Record 14 of Set 27 | raudeberg
# Processing Record 15 of Set 27 | sandwick
# Processing Record 16 of Set 27 | sturgis
# Processing Record 17 of Set 27 | korla
# Processing Record 18 of Set 27 | sabha
# Processing Record 19 of Set 27 | kincardine
# Processing Record 20 of Set 27 | churapcha
# Processing Record 21 of Set 27 | vostok
# Processing Record 22 of Set 27 | aksarka
# Processing Record 23 of Set 27 | ayan
# Processing Record 24 of Set 27 | lekoni
# Processing Record 25 of Set 27 | mwinilunga
# Processing Record 26 of Set 27 | walvis bay
# Processing Record 27 of Set 27 | montepuez
# Processing Record 28 of Set 27 | ulaanbaatar
# Processing Record 29 of Set 27 | milyutinskaya
# Processing Record 30 of Set 27 | bago
# Processing Record 31 of Set 27 | culebra
# Processing Record 32 of Set 27 | sao paulo de olivenca
# Processing Record 33 of Set 27 | okhotsk
# Processing Record 34 of Set 27 | lufilufi
# Processing Record 35 of Set 27 | zelenoborsk
# Processing Record 36 of Set 27 | anahuac
# Processing Record 37 of Set 27 | contamana
# Processing Record 38 of Set 27 | maceio
# Processing Record 39 of Set 27 | santa isabel
# Processing Record 40 of Set 27 | obihiro
# Processing Record 41 of Set 27 | atbasar
# Processing Record 42 of Set 27 | chapais
# Processing Record 43 of Set 27 | kanniyakumari
# Processing Record 44 of Set 27 | bonavista
# Processing Record 45 of Set 27 | bodoco
# City not found. Skipping...
# Processing Record 46 of Set 27 | dunedin
# Processing Record 47 of Set 27 | santiago del estero
# Processing Record 48 of Set 27 | falam
# Processing Record 49 of Set 27 | danshui
# Processing Record 50 of Set 27 | suntar
# Processing Record 1 of Set 28 | honiara
# Processing Record 2 of Set 28 | boyolangu
# Processing Record 3 of Set 28 | quatre cocos
# Processing Record 4 of Set 28 | san carlos de bariloche
# Processing Record 5 of Set 28 | palkino
# Processing Record 6 of Set 28 | rio de jesus
# Processing Record 7 of Set 28 | ahipara
# Processing Record 8 of Set 28 | mogadishu
# Processing Record 9 of Set 28 | porto santo
# Processing Record 10 of Set 28 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 28 | likasi
# Processing Record 12 of Set 28 | marzuq
# Processing Record 13 of Set 28 | tancitaro
# Processing Record 14 of Set 28 | pingdingshan
# Processing Record 15 of Set 28 | qasigiannguit
# Processing Record 16 of Set 28 | san angelo
# Processing Record 17 of Set 28 | eydhafushi
# Processing Record 18 of Set 28 | ukmerge
# Processing Record 19 of Set 28 | upata
# Processing Record 20 of Set 28 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 28 | suriapet
# Processing Record 22 of Set 28 | barra
# Processing Record 23 of Set 28 | kaduqli
# Processing Record 24 of Set 28 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 28 | san andres
# Processing Record 26 of Set 28 | neverkino
# Processing Record 27 of Set 28 | yevpatoriya
# Processing Record 28 of Set 28 | filingue
# Processing Record 29 of Set 28 | torquay
# Processing Record 30 of Set 28 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 28 | ous
# Processing Record 32 of Set 28 | lima
# Processing Record 33 of Set 28 | starokozache
# Processing Record 34 of Set 28 | chapada dos guimaraes
# Processing Record 35 of Set 28 | oistins
# Processing Record 36 of Set 28 | severomuysk
# Processing Record 37 of Set 28 | antofagasta
# Processing Record 38 of Set 28 | deputatskiy
# Processing Record 39 of Set 28 | copala
# Processing Record 40 of Set 28 | bahia de caraquez
# Processing Record 41 of Set 28 | agadez
# Processing Record 42 of Set 28 | iracoubo
# Processing Record 43 of Set 28 | porto nacional
# Processing Record 44 of Set 28 | keroka
# Processing Record 45 of Set 28 | riachao
# Processing Record 46 of Set 28 | samarai
# Processing Record 47 of Set 28 | bahir dar
# Processing Record 48 of Set 28 | garowe
# Processing Record 49 of Set 28 | inegol
# Processing Record 50 of Set 28 | banjar
# Processing Record 1 of Set 29 | orange cove
# Processing Record 2 of Set 29 | alice springs
# Processing Record 3 of Set 29 | matay
# Processing Record 4 of Set 29 | vestmannaeyjar
# Processing Record 5 of Set 29 | treuchtlingen
# Processing Record 6 of Set 29 | bismarck
# Processing Record 7 of Set 29 | nokaneng
# Processing Record 8 of Set 29 | alyangula
# Processing Record 9 of Set 29 | junction city
# Processing Record 10 of Set 29 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 29 | la rochelle
# Processing Record 12 of Set 29 | pitimbu
# Processing Record 13 of Set 29 | severnyy
# Processing Record 14 of Set 29 | tezpur
# Processing Record 15 of Set 29 | rasra
# Processing Record 16 of Set 29 | naze
# Processing Record 17 of Set 29 | husavik
# Processing Record 18 of Set 29 | pangody
# Processing Record 19 of Set 29 | tezu
# Processing Record 20 of Set 29 | kununurra
# Processing Record 21 of Set 29 | khani
# Processing Record 22 of Set 29 | puerto colombia
# Processing Record 23 of Set 29 | kuragino
# Processing Record 24 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 29 | bunbury
# Processing Record 26 of Set 29 | matata
# Processing Record 27 of Set 29 | goundam
# Processing Record 28 of Set 29 | hailar
# Processing Record 29 of Set 29 | codrington
# Processing Record 30 of Set 29 | doha
# Processing Record 31 of Set 29 | beyneu
# Processing Record 32 of Set 29 | ishinomaki
# Processing Record 33 of Set 29 | quzhou
# Processing Record 34 of Set 29 | klaksvik
# Processing Record 35 of Set 29 | emba
# Processing Record 36 of Set 29 | alangayam
# Processing Record 37 of Set 29 | ust-shonosha
# Processing Record 38 of Set 29 | iskilip
# Processing Record 39 of Set 29 | las vegas
# Processing Record 40 of Set 29 | ostersund
# Processing Record 41 of Set 29 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 29 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 29 | vinh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Paita  -5.0892  -81.1144     82.40        61           0
# 1        Tiarei -17.5333 -149.3333     87.80        62          75
# 2        Dingle  10.9995  122.6711     74.73        87          68
# 3  Punta Arenas -53.1500  -70.9167     53.60        58          40
# 4       Rikitea -23.1203 -134.9692     78.73        72           0
# 5        Durant  33.9940  -96.3708     71.60        33           1
# 6       Mataura -46.1927  168.8643     60.01        91          65
# 7         Pevek  69.7008  170.3133    -18.06        95          85
# 8      Hermanus -34.4187   19.2345     61.00        91         100
# 9          Hilo  19.7297 -155.0900     77.00        57          75
#
#    Wind Speed Weather Description Country                 Date
# 0       11.50           clear sky      PE  2021-04-10 21:29:56
# 1        5.75          light rain      PF  2021-04-10 21:29:57
# 2        6.02          light rain      PH  2021-04-10 21:29:57
# 3        6.91    scattered clouds      CL  2021-04-10 21:26:00
# 4       10.02          light rain      PF  2021-04-10 21:29:57
# 5       17.27           clear sky      US  2021-04-10 21:29:58
# 6        3.00       broken clouds      NZ  2021-04-10 21:29:58
# 7        1.88     overcast clouds      RU  2021-04-10 21:29:58
# 8        1.01     overcast clouds      ZA  2021-04-10 21:29:59
# 9        8.05       broken clouds      US  2021-04-10 21:29:59

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 690 non-null    object
#  1   Lat                  690 non-null    float64
#  2   Lng                  690 non-null    float64
#  3   Max Temp             690 non-null    float64
#  4   Humidity             690 non-null    int64
#  5   Cloudiness           690 non-null    int64
#  6   Wind Speed           690 non-null    float64
#  7   Weather Description  690 non-null    object
#  8   Country              690 non-null    object
#  9   Date                 690 non-null    object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 54.0+ KB

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
